# %%
# !pip install -r ../requirements.txt

# %%
import pandas as pd

# %%
df = pd.read_csv("../leaderboard.csv")
df
# Out:
#                                   Model Name  WER (%)  CER (%)  \
# 0   nvidia/stt_fa_fastconformer_hybrid_large     3.41     1.14
# 1   nvidia/stt_fa_fastconformer_hybrid_large     3.42     1.14
# 2                                dummy_model     6.10     3.80
# 3             facebook/seamless-m4t-v2-large    12.58     3.22
# 4             facebook/seamless-m4t-v2-large    12.63     3.23
# ..                                       ...      ...      ...
# 60                       openai/whisper-base    98.45    73.44
# 61                       facebook/mms-1b-all   102.63    84.60
# 62                      openai/whisper-small   104.43    97.43
# 63            distil-whisper/distil-large-v3   117.89   109.38
# 64          distil-whisper/distil-large-v3.5   131.01   115.65
#
#    Inference Time (s)                  Dataset Used  Sample Size  \
# 0                 31s  hsekhalilian/commonvoice dev         1000
# 1                 10s  hsekhalilian/commonvoice dev         1000
# ...
