# %%
# !pip install -r ../requirements.txt

# %%
import pandas as pd

# %%
df = pd.read_csv("../leaderboard.csv")
df
# Out:
#     Rank                                         Model Name  WER (%)  CER (%)  \
# 0      1           nvidia/stt_fa_fastconformer_hybrid_large     3.42     1.14
# 1      2                                        dummy_model     6.10     3.80
# 2      3  MohammadGholizadeh/whisper-large-v3-persian-co...    13.04     3.92
# 3      4                     Neurai/NeuraSpeech_WhisperBase    14.03     4.34
# 4      5                 hsekhalilian/wav2vec2-custom-model    15.44     3.21
# 5      6                            Neurai/NeuraSpeech_900h    15.71     5.66
# 6      7                 hsekhalilian/wav2vec2-custom-model    17.61     5.71
# 7      8      jonatasgrosman/wav2vec2-large-xlsr-53-persian    18.29     4.37
# 8      9           m3hrdadfi/wav2vec2-large-xlsr-persian-v2    21.39     5.06
# 9     10  MohammadGholizadeh/whisper-large-v3-persian-co...    23.49     6.22
# 10    11  MohammadGholizadeh/whisper-large-v3-persian-co...    23.58     6.88
# ...
