# %%
# !pip install -r ../requirements.txt

# %%
import pandas as pd

# %%
df = pd.read_csv("../leaderboard.csv")
df
# Out:
#     Rank                                         Model Name  WER (%)  CER (%)  \
# 0      1           nvidia/stt_fa_fastconformer_hybrid_large     3.42     1.14
# 1      2                                        dummy_model     6.10     3.80
# 2      3                     facebook/seamless-m4t-v2-large    12.58     3.22
# 3      4                     facebook/seamless-m4t-v2-large    12.63     3.23
# 4      5                     facebook/seamless-m4t-v2-large    12.71     3.22
# 5      5                        facebook/seamless-m4t-large    12.71     3.22
# 6      5                       facebook/seamless-m4t-medium    12.71     3.22
# 7      8  MohammadGholizadeh/whisper-large-v3-persian-co...    13.04     3.92
# 8      9                     Neurai/NeuraSpeech_WhisperBase    14.03     4.34
# 9     10                 hsekhalilian/wav2vec2-custom-model    15.44     3.21
# 10    11                            Neurai/NeuraSpeech_900h    15.71     5.66
# ...
