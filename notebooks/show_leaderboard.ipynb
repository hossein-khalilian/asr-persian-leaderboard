# %%
# !pip install -r ../requirements.txt

# %%
import pandas as pd

# %%
df = pd.read_csv("../leaderboard.csv")
df
# Out:
#     Rank                                     Model Name  WER (%)  CER (%)  \
# 0      1                                    dummy_model     6.10     3.80
# 1      2             hsekhalilian/wav2vec2-custom-model    15.44     3.21
# 2      3             hsekhalilian/wav2vec2-custom-model    17.61     5.71
# 3      4  jonatasgrosman/wav2vec2-large-xlsr-53-persian    18.29     4.37
# 4      5       m3hrdadfi/wav2vec2-large-xlsr-persian-v2    21.39     5.06
# 5      6             hsekhalilian/wav2vec2-custom-model    24.41     5.43
# 6      7                       ghofrani/xls-r-1b-fa-cv8    25.25     5.71
# 7      8             hsekhalilian/wav2vec2-custom-model    25.39     5.65
# 8      9       m3hrdadfi/wav2vec2-large-xlsr-persian-v3    26.10     6.45
# 9     10       m3hrdadfi/wav2vec2-large-xlsr-persian-v3    28.16     7.80
# 10    11       m3hrdadfi/wav2vec2-large-xlsr-persian-v3    28.53     7.12
# 11    12                       ghofrani/xls-r-1b-fa-cv8    29.78     8.57
# ...
