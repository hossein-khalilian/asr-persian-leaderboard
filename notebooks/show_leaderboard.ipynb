# %%
import pandas as pd

# %%
df = pd.read_csv("../leaderboard.csv")
df
# Out:
#     Rank                                     Model Name  WER (%)  CER (%)  \
# 0      1                                    dummy_model     6.10     3.80
# 1      2  jonatasgrosman/wav2vec2-large-xlsr-53-persian    18.29     4.37
# 2      3       m3hrdadfi/wav2vec2-large-xlsr-persian-v2    21.39     5.06
# 3      4             hsekhalilian/wav2vec2-custom-model    24.41     5.43
# 4      5                       ghofrani/xls-r-1b-fa-cv8    25.25     5.71
# 5      6             hsekhalilian/wav2vec2-custom-model    25.39     5.65
# 6      7       m3hrdadfi/wav2vec2-large-xlsr-persian-v3    26.10     6.45
# 7      8       m3hrdadfi/wav2vec2-large-xlsr-persian-v3    28.16     7.80
# 8      9       m3hrdadfi/wav2vec2-large-xlsr-persian-v3    28.53     7.12
# 9     10    m3hrdadfi/wav2vec2-large-xlsr-persian-shemo    34.56     8.68
# 10    11                        openai/whisper-large-v3    38.09    11.39
# 11    12                        openai/whisper-large-v3    41.38    16.53
# ...
